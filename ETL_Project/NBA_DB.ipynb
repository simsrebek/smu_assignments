# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
all_seasons = "all_seasons.csv"
all_seasons_df = pd.read_csv(all_seasons)
all_seasons_df.head()
# Out:
#    Unnamed: 0      player_name team_abbreviation   age  player_height  \
# 0           0   Chris Robinson               VAN  23.0         195.58
# 1           1        Matt Fish               MIA  27.0         210.82
# 2           2     Matt Bullard               HOU  30.0         208.28
# 3           3     Marty Conlon               BOS  29.0         210.82
# 4           4  Martin Muursepp               DAL  22.0         205.74
#
#    player_weight                    college country draft_year draft_round  \
# 0       90.71840           Western Kentucky     USA       1996           2
# 1      106.59412  North Carolina-Wilmington     USA       1992           2
# 2      106.59412                       Iowa     USA  Undrafted   Undrafted
# 3      111.13004                 Providence     USA  Undrafted   Undrafted
# 4      106.59412                       None     USA       1996           1
#
#    ...  pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# 0  ...  4.6  1.7  1.6       -11.4     0.039     0.088    0.155   0.486
# 1  ...  0.3  0.8  0.0       -15.1     0.143     0.267    0.265   0.333
# 2  ...  4.5  1.6  0.9         0.9     0.016     0.115    0.151   0.535
# 3  ...  7.8  4.4  1.4        -9.0     0.083     0.152    0.167   0.542
# 4  ...  3.7  1.6  0.5       -14.5     0.109     0.118    0.233   0.482
#
#    ast_pct   season
# 0    0.156  1996-97
# 1    0.000  1996-97
# 2    0.099  1996-97
# 3    0.101  1996-97
# 4    0.114  1996-97
#
# [5 rows x 22 columns]

# %%
# Create look up table for team_abbreviation
team = pd.DataFrame(all_seasons_df.team_abbreviation.unique())
team.columns = ['team_name']
team.insert(0, 'team_id', range(1, 1 + len(team)))
team
team.head(-10)
# Out:
#     team_id team_name
# 0         1       VAN
# 1         2       MIA
# 2         3       HOU
# 3         4       BOS
# 4         5       DAL
# 5         6       TOR
# 6         7       CLE
# 7         8       GSW
# 8         9       IND
# 9        10       PHI
# 10       11       PHX
# 11       12       POR
# 12       13       LAC
# 13       14       CHH
# 14       15       SAC
# 15       16       CHI
# 16       17       NYK
# 17       18       DET
# 18       19       LAL
# 19       20       ORL
# 20       21       SEA
# 21       22       WAS
# 22       23       SAS
# 23       24       ATL
# 24       25       NJN
# 25       26       UTA

# %%
# Create look up table for team_abbreviation
players = pd.DataFrame(all_seasons_df.player_name.unique())
players.columns = ['players_name']
players.insert(0, 'players_id', range(1, 1 + len(players)))
players
players.head()
# Out:
#    players_id     players_name
# 0           1   Chris Robinson
# 1           2        Matt Fish
# 2           3     Matt Bullard
# 3           4     Marty Conlon
# 4           5  Martin Muursepp

# %%
# Create look up table for college
college = pd.DataFrame(all_seasons_df.college.unique())
college.columns = ['college_name']
college.insert(0, 'college_id', range(1, 1 + len(college)))
college
# Out:
#      college_id               college_name
# 0             1           Western Kentucky
# 1             2  North Carolina-Wilmington
# 2             3                       Iowa
# 3             4                 Providence
# 4             5                       None
# ..          ...                        ...
# 283         284                       UNLV
# 284         285              Georgia State
# 285         286                        USC
# 286         287                    Ohio U.
# 287         288               Miami (Fla.)
#
# [288 rows x 2 columns]

# %%
# Create look up table for country
country = pd.DataFrame(all_seasons_df.country.unique())
country.columns = ['country_name']
country.insert(0, 'country_id', range(1, 1 + len(country)))
country
# Out:
#     country_id           country_name
# 0            1                    USA
# 1            2                Jamaica
# 2            3                 Canada
# 3            4                Croatia
# 4            5  Serbia and Montenegro
# ..         ...                    ...
# 64          65             Cabo Verde
# 65          66            South Sudan
# 66          67                Bahamas
# 67          68                  Ghana
# 68          69                Austria
#
# [69 rows x 2 columns]

# %%
# Split all_seasons_df in two
# Demographic and Stat.
demographic = all_seasons_df[['player_name', 'team_abbreviation', 'age', 'player_height','player_weight',
                             'college', 'country','draft_year','draft_round','draft_number']]
stat = all_seasons_df[['player_name', 'gp', 'pts', 'reb','ast','net_rating','oreb_pct','dreb_pct','usg_pct','ts_pct','ast_pct',
                      'season']]
print(demographic.head())
print(stat.head())
# Out:
#        player_name team_abbreviation   age  player_height  player_weight  \
# 0   Chris Robinson               VAN  23.0         195.58       90.71840
# 1        Matt Fish               MIA  27.0         210.82      106.59412
# 2     Matt Bullard               HOU  30.0         208.28      106.59412
# 3     Marty Conlon               BOS  29.0         210.82      111.13004
# 4  Martin Muursepp               DAL  22.0         205.74      106.59412
#
#                      college country draft_year draft_round draft_number
# 0           Western Kentucky     USA       1996           2           51
# 1  North Carolina-Wilmington     USA       1992           2           50
# 2                       Iowa     USA  Undrafted   Undrafted    Undrafted
# 3                 Providence     USA  Undrafted   Undrafted    Undrafted
# 4                       None     USA       1996           1           25
#        player_name  gp  pts  reb  ast  net_rating  oreb_pct  dreb_pct  \
# 0   Chris Robinson  41  4.6  1.7  1.6       -11.4     0.039     0.088
# 1        Matt Fish   6  0.3  0.8  0.0       -15.1     0.143     0.267
# 2     Matt Bullard  71  4.5  1.6  0.9         0.9     0.016     0.115
# 3     Marty Conlon  74  7.8  4.4  1.4        -9.0     0.083     0.152
# 4  Martin Muursepp  42  3.7  1.6  0.5       -14.5     0.109     0.118
#
#    usg_pct  ts_pct  ast_pct   season
# 0    0.155   0.486    0.156  1996-97
# 1    0.265   0.333    0.000  1996-97
# 2    0.151   0.535    0.099  1996-97
# 3    0.167   0.542    0.101  1996-97
# 4    0.233   0.482    0.114  1996-97

# %%
# Put ids
demographic['players_id'] = demographic['player_name'].map(players.set_index('players_name')['players_id'])
demographic['team_id'] = demographic['team_abbreviation'].map(team.set_index('team_name')['team_id'])
demographic['college_id'] = demographic['college'].map(college.set_index('college_name')['college_id'])
demographic['country_id'] = demographic['country'].map(country.set_index('country_name')['country_id'])
# Out:
# C:\Users\Bek\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Bek\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Bek\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Bek\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
demographic.head()
# Out:
#        player_name team_abbreviation   age  player_height  player_weight  \
# 0   Chris Robinson               VAN  23.0         195.58       90.71840
# 1        Matt Fish               MIA  27.0         210.82      106.59412
# 2     Matt Bullard               HOU  30.0         208.28      106.59412
# 3     Marty Conlon               BOS  29.0         210.82      111.13004
# 4  Martin Muursepp               DAL  22.0         205.74      106.59412
#
#                      college country draft_year draft_round draft_number  \
# 0           Western Kentucky     USA       1996           2           51
# 1  North Carolina-Wilmington     USA       1992           2           50
# 2                       Iowa     USA  Undrafted   Undrafted    Undrafted
# 3                 Providence     USA  Undrafted   Undrafted    Undrafted
# 4                       None     USA       1996           1           25
#
#    players_id  team_id  college_id  country_id
# 0           1        1           1           1
# 1           2        2           2           1
# 2           3        3           3           1
# 3           4        4           4           1
# 4           5        5           5           1

# %%
season78 = "season78.csv"
season78_df = pd.read_csv(season78)
season78_df.head()
# Out:
#    Season           Player   WS
# 0    1979      Aaron James  1.7
# 1    1979  Adrian Dantley*  5.7
# 2    1979       Al Skinner  1.2
# 3    1979    Alex English*  7.0
# 4    1979    Allan Bristow  3.5

# %%
season78_df["Player"]= season78_df["Player"].str.split("*", n = 1, expand = True)
season78_df.head()
# Out:
#    Season          Player   WS
# 0    1979     Aaron James  1.7
# 1    1979  Adrian Dantley  5.7
# 2    1979      Al Skinner  1.2
# 3    1979    Alex English  7.0
# 4    1979   Allan Bristow  3.5

# %%
season78_df
# Out:
#        Season          Player   WS
# 0        1979     Aaron James  1.7
# 1        1979  Adrian Dantley  5.7
# 2        1979      Al Skinner  1.2
# 3        1979    Alex English  7.0
# 4        1979   Allan Bristow  3.5
# ...       ...             ...  ...
# 15308    2016     Willie Reed  1.2
# 15309    2016  Xavier Munford  0.1
# 15310    2016     Zach LaVine  2.6
# 15311    2016   Zach Randolph  4.3
# 15312    2016   Zaza Pachulia  6.0
#
# [15313 rows x 3 columns]

# %%
#season78_df["name_year"] = season78_df["Player"] + " " + season78_df["Season"].map(str)
#season78_df.head()

# %%
season78_df['players_id'] = season78_df['Player'].map(players.set_index('players_name')['players_id'])
#season78_df = season78_df["players_id"].fillna(0, inplace = True)
#season78_df.Players_ID = season78_df.Players_ID.astype(int)
season78_df.head(-10)
# Out:
#        Season          Player   WS  players_id
# 0        1979     Aaron James  1.7         NaN
# 1        1979  Adrian Dantley  5.7         NaN
# 2        1979      Al Skinner  1.2         NaN
# 3        1979    Alex English  7.0         NaN
# 4        1979   Allan Bristow  3.5         NaN
# ...       ...             ...  ...         ...
# 15298    2016      Tyus Jones  0.3      1759.0
# 15299    2016   Udonis Haslem  0.4       904.0
# 15300    2016  Victor Oladipo  4.9      1626.0
# 15301    2016    Vince Carter  1.8       595.0
# 15302    2016  Walter Tavares  0.2         NaN
#
# [15303 rows x 4 columns]

# %%
stat['players_id'] = stat['player_name'].map(players.set_index('players_name')['players_id'])
stat.head()
# Out:
# C:\Users\Bek\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        player_name  gp  pts  reb  ast  net_rating  oreb_pct  dreb_pct  \
# 0   Chris Robinson  41  4.6  1.7  1.6       -11.4     0.039     0.088
# 1        Matt Fish   6  0.3  0.8  0.0       -15.1     0.143     0.267
# 2     Matt Bullard  71  4.5  1.6  0.9         0.9     0.016     0.115
# 3     Marty Conlon  74  7.8  4.4  1.4        -9.0     0.083     0.152
# 4  Martin Muursepp  42  3.7  1.6  0.5       -14.5     0.109     0.118
#
#    usg_pct  ts_pct  ast_pct   season  players_id
# 0    0.155   0.486    0.156  1996-97           1
# 1    0.265   0.333    0.000  1996-97           2
# 2    0.151   0.535    0.099  1996-97           3
# 3    0.167   0.542    0.101  1996-97           4
# 4    0.233   0.482    0.114  1996-97           5

# %%
# 3 Main Dataframes and 4 lookup tables
# 3 Mains are: stat, season78_df and demographic
# 4 lookups are: players, team, college, country

# %%
stat = stat.drop(columns=['player_name'])
stat.head()
# Out:
#    gp  pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# 0  41  4.6  1.7  1.6       -11.4     0.039     0.088    0.155   0.486
# 1   6  0.3  0.8  0.0       -15.1     0.143     0.267    0.265   0.333
# 2  71  4.5  1.6  0.9         0.9     0.016     0.115    0.151   0.535
# 3  74  7.8  4.4  1.4        -9.0     0.083     0.152    0.167   0.542
# 4  42  3.7  1.6  0.5       -14.5     0.109     0.118    0.233   0.482
#
#    ast_pct   season  players_id
# 0    0.156  1996-97           1
# 1    0.000  1996-97           2
# 2    0.099  1996-97           3
# 3    0.101  1996-97           4
# 4    0.114  1996-97           5

# %%
demographic = demographic.drop(columns=['player_name', 'team_abbreviation','college','country'])
demographic.head()
# Out:
#     age  player_height  player_weight draft_year draft_round draft_number  \
# 0  23.0         195.58       90.71840       1996           2           51
# 1  27.0         210.82      106.59412       1992           2           50
# 2  30.0         208.28      106.59412  Undrafted   Undrafted    Undrafted
# 3  29.0         210.82      111.13004  Undrafted   Undrafted    Undrafted
# 4  22.0         205.74      106.59412       1996           1           25
#
#    players_id  team_id  college_id  country_id
# 0           1        1           1           1
# 1           2        2           2           1
# 2           3        3           3           1
# 3           4        4           4           1
# 4           5        5           5           1

# %%
season78_df = season78_df.drop(columns=['Player'])
season78_df.head(-10)
# Out:
#        Season   WS  players_id
# 0        1979  1.7         NaN
# 1        1979  5.7         NaN
# 2        1979  1.2         NaN
# 3        1979  7.0         NaN
# 4        1979  3.5         NaN
# ...       ...  ...         ...
# 15298    2016  0.3      1759.0
# 15299    2016  0.4       904.0
# 15300    2016  4.9      1626.0
# 15301    2016  1.8       595.0
# 15302    2016  0.2         NaN
#
# [15303 rows x 3 columns]

# %%
season78_df = season78_df.rename(columns={"Season": "season", "WS": "ws"})
season78_df.head()
# Out:
#    season   ws  players_id
# 0    1979  1.7         NaN
# 1    1979  5.7         NaN
# 2    1979  1.2         NaN
# 3    1979  7.0         NaN
# 4    1979  3.5         NaN

# %%
season78_df = season78_df.dropna(subset=['players_id'])

# %%
season78_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11071 entries, 30 to 15312
# Data columns (total 3 columns):
# season        11071 non-null int64
# ws            11071 non-null float64
# players_id    11071 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 346.0 KB

# %%
rds_connection_string = "postgres:Pgadmin@localhost:5432/NBA_DB"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2264         try:
# -> 2265             return fn()
#    2266         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-56-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2241         """
#    2242
# -> 2243         with self._optional_conn_ctx_manager(connection) as conn:
#    2244             if not schema:
#    2245                 schema = self.dialect.default_schema_name
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2025     def _optional_conn_ctx_manager(self, connection=None):
#    2026         if connection is None:
# -> 2027             with self._contextual_connect() as conn:
#    2028                 yield conn
#    2029         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2227         return self._connection_cls(
#    2228             self,
# -> 2229             self._wrap_pool_connect(self.pool.connect, None),
#    2230             close_with_result=close_with_result,
#    2231             **kwargs
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2267             if connection is None:
#    2268                 Connection._handle_dbapi_exception_noconnection(
# -> 2269                     e, dialect, self
#    2270                 )
#    2271             else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1534             util.raise_from_cause(newraise, exc_info)
#    1535         elif should_wrap:
# -> 1536             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1537         else:
#    1538             util.reraise(*exc_info)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2263         dialect = self.dialect
#    2264         try:
# -> 2265             return fn()
#    2266         except dialect.dbapi.Error as e:
#    2267             if connection is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     451
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#     455     def create_connect_args(self, url):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
players.to_sql(name='players', con=engine, if_exists='replace', index=False)
season78_df.to_sql(name='season78', con=engine, if_exists='replace', index=False)
stat.to_sql(name='stat', con=engine, if_exists='replace', index=False)
demographic.to_sql(name='demographic', con=engine, if_exists='replace', index=False)
team.to_sql(name='team', con=engine, if_exists='replace', index=False)
college.to_sql(name='college', con=engine, if_exists='replace', index=False)
country.to_sql(name='country', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2264         try:
# -> 2265             return fn()
#    2266         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-25-3889548a7699> in <module>
# ----> 1 players.to_sql(name='players', con=engine, if_exists='replace', index=False)
#       2 season78_df.to_sql(name='season78', con=engine, if_exists='replace', index=False)
#       3 stat.to_sql(name='stat', con=engine, if_exists='replace', index=False)
#       4 demographic.to_sql(name='demographic', con=engine, if_exists='replace', index=False)
#       5 team.to_sql(name='team', con=engine, if_exists='replace', index=False)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1317             dtype=dtype,
#    1318         )
# -> 1319         table.create()
#    1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     639
#     640     def create(self):
# --> 641         if self.exists():
#     642             if self.if_exists == "fail":
#     643                 raise ValueError(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in exists(self)
#     626
#     627     def exists(self):
# --> 628         return self.pd_sql.has_table(self.name, self.schema)
#     629
#     630     def sql_schema(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1342     def has_table(self, name, schema=None):
#    1343         return self.connectable.run_callable(
# -> 1344             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1345         )
#    1346
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2147
#    2148         """
# -> 2149         with self._contextual_connect() as conn:
#    2150             return conn.run_callable(callable_, *args, **kwargs)
#    2151
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2227         return self._connection_cls(
#    2228             self,
# -> 2229             self._wrap_pool_connect(self.pool.connect, None),
#    2230             close_with_result=close_with_result,
#    2231             **kwargs
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2267             if connection is None:
#    2268                 Connection._handle_dbapi_exception_noconnection(
# -> 2269                     e, dialect, self
#    2270                 )
#    2271             else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1534             util.raise_from_cause(newraise, exc_info)
#    1535         elif should_wrap:
# -> 1536             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1537         else:
#    1538             util.reraise(*exc_info)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2263         dialect = self.dialect
#    2264         try:
# -> 2265             return fn()
#    2266         except dialect.dbapi.Error as e:
#    2267             if connection is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     451
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#     455     def create_connect_args(self, url):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
#stat.to_sql(name='stat', con=engine, if_exists='append', index=False)
#demographic.to_sql(name='demographic', con=engine, if_exists='append', index=False)
#team.to_sql(name='team', con=engine, if_exists='append', index=False)
#college.to_sql(name='college', con=engine, if_exists='append', index=False)
#country.to_sql(name='country', con=engine, if_exists='append', index=False)

# %%
#demographic.to_sql(name='demographic',if_exists='replace', con=engine, index=False)

# %%
#season78_df.to_sql(name='season78', con=engine, if_exists='replace', index=False)

# %%
#stat.to_sql(name='stat', con=engine, if_exists='replace', index=False)

# %%
stat.to_sql(name='stat', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from season78', con=engine)
# Out:
#        season   ws  players_id
# 0        1979  7.7      1154.0
# 1        1979  6.3       434.0
# 2        1979  3.6        66.0
# 3        1979  3.4       824.0
# 4        1979  7.1       169.0
# ...       ...  ...         ...
# 11066    2016  1.2      1755.0
# 11067    2016  0.1      1754.0
# 11068    2016  2.6      1672.0
# 11069    2016  4.3       795.0
# 11070    2016  6.0       908.0
#
# [11071 rows x 3 columns]
